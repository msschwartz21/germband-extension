# %% [markdown]
# # Goal
# In order to use our vector flow data to track germband extension, we need identify the position of the berm band in the image. As a first approach, I would like to work off the validation method proposed in Vig et al. 2016 where seed points are placed in the vector field and their position is updated voer time.
#
# For preliminary testing, the starting point of the gerbmand will be assigned by the user.

# %%
import pandas as pd
import numpy as np

import scipy.interpolate as interp

import matplotlib.pyplot as plt

from imp import reload
import gbeflow

# %%
df = gbeflow.tidy_vector_data('test4')

# %% [markdown]
# Let's also load in the raw data so that we can determine the position of our starting point.

# %%
rawpath = '../data/wt_gbe_20180110_mask.h5'
hst = gbeflow.read_hyperstack(rawpath)

# %%
gbeflow.imshow(hst[0])
start = (50,550)
plt.scatter(start[0],start[1],c='r')
