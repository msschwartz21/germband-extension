# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
from imp import reload

# %%
import utility as ut

# %%
reload(ut)
# Out:
# <module 'utility' from '/Users/Morgan/Desktop/Caltech/Stathopoulos Rotation/GBE_analysis/utility.py'>

# %%
hstack = ut.read_hyperstack(':Users:Morgan:Desktop:wt_gbe_20180110.h5')

# %%
f = h5py.File(':Users:Morgan:Desktop:wt_gbe_20180110.h5','r')

# %%
data = f.get('t0')

# %%
type(data)
# Out:
# h5py._hl.group.Group

# %%
channel = data.get('channel0')

# %%
type(channel)
# Out:
# h5py._hl.dataset.Dataset

# %%
fig,ax = plt.subplots()
ax.imshow(channel)

# %%
f?
# Out:
# Type:           File
# String form:    <HDF5 file "wt_gbe_20180110" (mode r+)>
# Length:         0
# File:           /anaconda3/lib/python3.6/site-packages/h5py/_hl/files.py
# Docstring:      Represents an HDF5 file.
# Init docstring:
# Create a new file object.
#
# See the h5py user guide for a detailed explanation of the options.
#
# name
#     Name of the file on disk.  Note: for files created with the 'core'
#     driver, HDF5 still requires this be non-empty.
# mode
#     r        Readonly, file must exist
#     r+       Read/write, file must exist
#     w        Create file, truncate if exists
#     w- or x  Create file, fail if exists
#     a        Read/write if exists, create otherwise (default)
# driver
#     Name of the driver to use.  Legal values are None (default,
#     recommended), 'core', 'sec2', 'stdio', 'mpio'.
# libver
#     Library version bounds.  Currently only the strings 'earliest'
#     and 'latest' are defined.
# userblock
# ...

# %%
type(data)
# Out:
# NoneType

# %%
f.keys()
# Out:
# KeysView(<HDF5 file "wt_gbe_20180110" (mode r+)>)
